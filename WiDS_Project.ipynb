# %% [markdown]
# # Women in Data Science Datathon 2025

# %% [markdown]
# ### Install basic packages for data science in Python

# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Categorical metadata

# %%
df_categorical_metadata = pd.read_excel('TRAIN_NEW/TRAIN_CATEGORICAL_METADATA_new.xlsx')
df_categorical_metadata.head()
# Out:
#   participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0   00aIpNTbG5uh                     2019                       4
# 1   00fV0OyyoLfw                     2017                       1
# 2   04X1eiS79T4B                     2017                       1
# 3   05ocQutkURd6                     2018                       1
# 4   06YUNBA9ZRLq                     2018                       1
#
#    PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                               1.0                          0.0
# 1                               0.0                          9.0
# 2                               1.0                          2.0
# 3                               3.0                          8.0
# 4                               0.0                          1.0
#
#    MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                      3.0                    21.0                    45.0
# ...

# %%
# Check for missing values in the categorical metadata
df_categorical_metadata.isna().sum()
# Out:
# participant_id                        0
# Basic_Demos_Enroll_Year               0
# Basic_Demos_Study_Site                0
# PreInt_Demos_Fam_Child_Ethnicity     43
# PreInt_Demos_Fam_Child_Race          54
# MRI_Track_Scan_Location               3
# Barratt_Barratt_P1_Edu               15
# Barratt_Barratt_P1_Occ               31
# Barratt_Barratt_P2_Edu              198
# Barratt_Barratt_P2_Occ              222
# dtype: int64

# %%
# Display missing values in the categorical metadata
missing_values = df_categorical_metadata[df_categorical_metadata.isna().any(axis=1)]
missing_values
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      00aIpNTbG5uh                     2019                       4
# 2      04X1eiS79T4B                     2017                       1
# 4      06YUNBA9ZRLq                     2018                       1
# 9      0i2Tz2XUL4vm                     2019                       1
# 15     0pGmIdpjGpXN                     2017                       3
# ...             ...                      ...                     ...
# 1198   ZrR6qlydACvG                     2017                       3
# 1200   zSOTbT8r7FQ2                     2016                       1
# 1203   ZuCLNLMndKHD                     2016                       3
# 1206   zW62ObiZfmKJ                     2017                       1
# 1208   zwjJWCRzKhDz                     2019                       4
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  1.0                          0.0
# ...

# %%
# Drop rows with missing values in the categorical metadata
df_categorical_metadata_cleaned = df_categorical_metadata.dropna()
# Display the cleaned categorical metadata
df_categorical_metadata_cleaned
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 1      00fV0OyyoLfw                     2017                       1
# 3      05ocQutkURd6                     2018                       1
# 5      0cduHhwrQN4r                     2017                       1
# 6      0FUWCjn9YMN1                     2017                       1
# 7      0Hthz5IFXhpw                     2016                       2
# ...             ...                      ...                     ...
# 1207   zwBG0rZ05Mcb                     2016                       1
# 1209   zwXD5v17Rx01                     2018                       1
# 1210   zWzLCi3NTBTd                     2018                       3
# 1211   Zy9GTHDxUbXU                     2019                       4
# 1212   Zye7yYRQohXi                     2017                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 1                                  0.0                          9.0
# ...

# %%
# Check for duplicates in the categorical metadata
duplicates = df_categorical_metadata_cleaned[df_categorical_metadata_cleaned.duplicated()]
# Display duplicates in the categorical metadata
duplicates
# Out:
# Empty DataFrame
# Columns: [participant_id, Basic_Demos_Enroll_Year, Basic_Demos_Study_Site, PreInt_Demos_Fam_Child_Ethnicity, PreInt_Demos_Fam_Child_Race, MRI_Track_Scan_Location, Barratt_Barratt_P1_Edu, Barratt_Barratt_P1_Occ, Barratt_Barratt_P2_Edu, Barratt_Barratt_P2_Occ]
# Index: []

# %%
import matplotlib.pyplot as plt

# Define columns and labels
barratt_columns = [
    'Barratt_Barratt_P1_Edu', 'Barratt_Barratt_P1_Occ', 
    'Barratt_Barratt_P2_Edu', 'Barratt_Barratt_P2_Occ'
]
barratt_labels = [
    'Parent 1 Education', 'Parent 1 Occupation', 
    'Parent 2 Education', 'Parent 2 Occupation'
]

# Figure size
plt.figure(figsize=(12, 6))

# Bar width and participant indices
bar_width = 0.2
participants = df_categorical_metadata_cleaned.index

# Plot bars for each category
for i, (col, label) in enumerate(zip(barratt_columns, barratt_labels)):
    if col in df_categorical_metadata_cleaned.columns:
        plt.bar(participants + i * bar_width, df_categorical_metadata_cleaned[col], width=bar_width, label=label, alpha=0.7)
    else:
        print(f"Warning: Column '{col}' not found in DataFrame!")

# Title and axis labels
plt.title('Barratt Features Across Participants')
plt.xlabel('Participant Index')
plt.ylabel('Barratt Score')
plt.xticks(participants + bar_width, participants, rotation=90)  # Adjust x-axis labels
plt.legend()
plt.grid(True, axis='y', alpha=0.3)

# Show the plot
plt.show()

# %%
# Lineplot for Barratt_Barratt_P1_Edu vs Barratt_Barratt_P1_Occ
plt.figure(figsize=(10,5))
sns.lineplot(
    x='Barratt_Barratt_P1_Edu', 
    y='Barratt_Barratt_P1_Occ', 
    data=df_categorical_metadata_cleaned, 
    marker='o'
)
plt.title('Lineplot: Barratt_Barratt_P1_Edu vs Barratt_Barratt_P1_Occ')
plt.xlabel('Barratt_Barratt_P1_Edu')
plt.ylabel('Barratt_Barratt_P1_Occ')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Lineplot for Barratt_Barratt_P2_Edu vs Barratt_Barratt_P2_Occ
plt.figure(figsize=(10,5))
sns.lineplot(
    x='Barratt_Barratt_P2_Edu', 
    y='Barratt_Barratt_P2_Occ', 
    data=df_categorical_metadata_cleaned, 
    marker='o'
)
plt.title('Lineplot: Barratt_Barratt_P2_Edu vs Barratt_Barratt_P2_Occ')
plt.xlabel('Barratt_Barratt_P2_Edu')
plt.ylabel('Barratt_Barratt_P2_Occ')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Lineplot for Barratt_Barratt_P1_Edu vs Barratt_Barratt_P2_Edu
plt.figure(figsize=(10,5))
sns.lineplot(
    x='Barratt_Barratt_P1_Edu', 
    y='Barratt_Barratt_P2_Edu', 
    data=df_categorical_metadata_cleaned, 
    marker='o'
)
plt.title('Lineplot: Barratt_Barratt_P1_Edu vs Barratt_Barratt_P2_Edu')
plt.xlabel('Barratt_Barratt_P1_Edu')
plt.ylabel('Barratt_Barratt_P2_Edu')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Lineplot for Barratt_Barratt_P1_Occ vs Barratt_Barratt_P2_Occ
plt.figure(figsize=(10,5))
sns.lineplot(
    x='Barratt_Barratt_P1_Occ', 
    y='Barratt_Barratt_P2_Occ', 
    data=df_categorical_metadata_cleaned, 
    marker='o'
)
plt.title('Lineplot: Barratt_Barratt_P1_Occ vs Barratt_Barratt_P2_Occ')
plt.xlabel('Barratt_Barratt_P1_Occ')
plt.ylabel('Barratt_Barratt_P2_Occ')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Quantative metadata

# %%
df_quantatative_metadata = pd.read_excel('TRAIN_NEW/TRAIN_QUANTITATIVE_METADATA_new.xlsx')
df_quantatative_metadata.head()
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   00aIpNTbG5uh         100.00                  13.0             3.0
# 1   00fV0OyyoLfw          92.27                  14.0             3.0
# 2   04X1eiS79T4B          86.67                  14.0             3.0
# 3   05ocQutkURd6          93.34                  14.0             3.0
# 4   06YUNBA9ZRLq           0.00                  14.0             8.0
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0            15.0             44.0             14.0            20.0
# 1            12.0             35.0             25.0            28.0
# 2            21.0             37.0             18.0            26.0
# 3            11.0             42.0             15.0            20.0
# 4            12.0             35.0             22.0            12.0
#
#    APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# ...

# %%
# Check for missing values in the quantitative metadata
df_quantatative_metadata.isna().sum()
# Out:
# participant_id                  0
# EHQ_EHQ_Total                  13
# ColorVision_CV_Score           23
# APQ_P_APQ_P_CP                 12
# APQ_P_APQ_P_ID                 12
# APQ_P_APQ_P_INV                12
# APQ_P_APQ_P_OPD                12
# APQ_P_APQ_P_PM                 12
# APQ_P_APQ_P_PP                 12
# SDQ_SDQ_Conduct_Problems        9
# SDQ_SDQ_Difficulties_Total      9
# SDQ_SDQ_Emotional_Problems      9
# SDQ_SDQ_Externalizing           9
# SDQ_SDQ_Generating_Impact       9
# SDQ_SDQ_Hyperactivity           9
# SDQ_SDQ_Internalizing           9
# SDQ_SDQ_Peer_Problems           9
# SDQ_SDQ_Prosocial               9
# MRI_Track_Age_at_Scan         360
# dtype: int64

# %%
# Track age at scan missing values
df_quantatative_metadata['MRI_Track_Age_at_Scan'].isna().sum()
# Out:
# np.int64(360)

# %%
df_quantatative_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              1213 non-null   object
#  1   EHQ_EHQ_Total               1200 non-null   float64
#  2   ColorVision_CV_Score        1190 non-null   float64
#  3   APQ_P_APQ_P_CP              1201 non-null   float64
#  4   APQ_P_APQ_P_ID              1201 non-null   float64
#  5   APQ_P_APQ_P_INV             1201 non-null   float64
#  6   APQ_P_APQ_P_OPD             1201 non-null   float64
#  7   APQ_P_APQ_P_PM              1201 non-null   float64
#  8   APQ_P_APQ_P_PP              1201 non-null   float64
#  9   SDQ_SDQ_Conduct_Problems    1204 non-null   float64
#  10  SDQ_SDQ_Difficulties_Total  1204 non-null   float64
#  11  SDQ_SDQ_Emotional_Problems  1204 non-null   float64
#  12  SDQ_SDQ_Externalizing       1204 non-null   float64
# ...

# %%
df_quantatative_metadata.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1200.000000           1190.000000     1201.000000     1201.000000
# mean       59.514750             13.419328        3.819317       13.337219
# std        49.744631              2.112830        1.330348        3.593562
# min      -100.000000              0.000000        2.000000        5.000000
# 25%        46.670000             14.000000        3.000000       11.000000
# 50%        77.800000             14.000000        3.000000       13.000000
# 75%        94.470000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1201.000000      1201.000000     1201.000000     1201.000000
# mean         39.767694        17.963364       16.557036       25.498751
# std           4.872729         3.333965        5.146548        3.053720
# ...

# %%
# Drop rows with missing values in the quantitative metadata
df_quantatative_metadata_cleaned = df_quantatative_metadata.dropna()
# Display the cleaned quantitative metadata
df_quantatative_metadata_cleaned
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0      00aIpNTbG5uh         100.00                  13.0             3.0
# 2      04X1eiS79T4B          86.67                  14.0             3.0
# 3      05ocQutkURd6          93.34                  14.0             3.0
# 4      06YUNBA9ZRLq           0.00                  14.0             8.0
# 6      0FUWCjn9YMN1         100.00                  14.0             4.0
# ...             ...            ...                   ...             ...
# 1206   zW62ObiZfmKJ         100.00                  14.0             3.0
# 1207   zwBG0rZ05Mcb          46.67                  13.0             3.0
# 1208   zwjJWCRzKhDz         100.00                  14.0             3.0
# 1209   zwXD5v17Rx01          46.67                  14.0             3.0
# 1210   zWzLCi3NTBTd         -40.00                  14.0             3.0
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# ...

# %%
# Statistics of cleaned quantitative metadata
df_quantatative_metadata_cleaned.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count     812.000000            812.000000      812.000000      812.000000
# mean       60.858485             13.401478        3.862069       13.450739
# std        48.095659              2.140306        1.378249        3.581193
# min      -100.000000              0.000000        2.000000        5.000000
# 25%        46.670000             14.000000        3.000000       11.000000
# 50%        77.800000             14.000000        3.000000       13.000000
# 75%        95.600000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count       812.000000       812.000000      812.000000      812.000000
# mean         39.703202        17.905172       16.644089       25.415025
# std           4.807191         3.295496        5.187501        3.081134
# ...

# %%
plt.figure(figsize=(10, 5))
sns.pairplot(
    df_quantatative_metadata_cleaned, 
    vars=['APQ_P_APQ_P_CP', 'APQ_P_APQ_P_PP', 'APQ_P_APQ_P_ID', 'APQ_P_APQ_P_INV', 'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM'], 
    diag_kind='kde', 
    plot_kws={'alpha': 0.6, 's': 50}, 
    diag_kws={'fill': True},
)
plt.suptitle('Pairplot of APQ Variables', y=1.02)
plt.show()

# %% [markdown]
# ### Functional connectivity matrices

# %%
df_functional_matrices = pd.read_csv('TRAIN_NEW/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES_new_36P_Pearson.csv')
df_functional_matrices.isna().sum()
# Out:
# participant_id          0
# 0throw_1thcolumn        0
# 0throw_2thcolumn        0
# 0throw_3thcolumn        0
# 0throw_4thcolumn        0
#                        ..
# 196throw_198thcolumn    0
# 196throw_199thcolumn    0
# 197throw_198thcolumn    0
# 197throw_199thcolumn    0
# 198throw_199thcolumn    0
# Length: 19901, dtype: int64

# %%
df_functional_matrices.head()
# Out:
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   70z8Q2xdTXM3          0.222930          0.527903          0.429966
# 1   WHWymJu6zNZi          0.614765          0.577255          0.496127
# 2   4PAQp1M6EyAo         -0.116833          0.458408          0.260703
# 3   obEacy4Of68I          0.199688          0.752714          0.658283
# 4   s7WzzDcmDOhF          0.227321          0.613268          0.621447
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.060457          0.566489          0.315342          0.508408
# 1          0.496606          0.404686          0.439724          0.122590
# 2          0.639031          0.769337          0.442528          0.637110
# 3          0.575096          0.692867          0.645789          0.522750
# 4          0.562673          0.736709          0.589813          0.266676
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# ...
